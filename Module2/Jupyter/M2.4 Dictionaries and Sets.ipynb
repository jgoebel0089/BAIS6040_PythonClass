# %% [markdown]
# # Data Programming in Python | BAIS:6040
# # Module 2.4 - Dictionaries and Sets

# %% [markdown]
# ### Topics to be covered:
# - ***Dictionaries (+ exercises)***
# - ***Sets (+ exercises)***

# %% [markdown]
# ## ▪ Python Collections

# %% [markdown]
# There are four types of collections in Python:
#
# - List
# - Tuple
# - ***Dictionary***
# - ***Set***
#
# You can choose the right collection type that fits your needs.

# %% [markdown]
# ## Dictionaries

# %% [markdown]
# A dictionary is a collection of key-value mappings that is unordered (from Python 3.7 and above, it is ordered), mutable, indexed, and written with curly brackets. It allows no duplicate keys.

# %% [markdown]
# If you look up a key in the dictionary, it returns its value, but not vice versa. When designing a dictionary, you should think about what should be the keys and what should be the values. It depends on the purpose of the dictionary.

# %%
d = {}
print(d, type(d))
# Out:
# {} <class 'dict'>

# %%
d = dict()
print(d, type(d))
# Out:
# {} <class 'dict'>

# %%
buildings = {"UCC": "University Capitol Center", "PBB": "Pappajohn Business Building", "PC": "Pomerantz Center"}
print(buildings, type(buildings))
# Out:
# {'UCC': 'University Capitol Center', 'PBB': 'Pappajohn Business Building', 'PC': 'Pomerantz Center'} <class 'dict'>

# %% [markdown]
# You can create a dictionary by listing its key-value pairs in a pair of matching curly braces. Each key and its value are separated by a colon.

# %% [markdown]
# `buildings` is a dictionary for UI building name abbreviations. If you look up an abbreviation, it returns its full name.

# %% [markdown]
# If you look up a key in a dictionary, it returns its value.

# %%
buildings["PC"]
# Out:
# 'Pomerantz Center'

# %% [markdown]
# If there is not the key in the dictionary, it returns KeyError.

# %%
buildings.keys()
# Out:
# dict_keys(['UCC', 'PBB', 'PC'])

# %%
buildings.values()
# Out:
# dict_values(['University Capitol Center', 'Pappajohn Business Building', 'Pomerantz Center'])

# %%
buildings["IMU"] = "Iowa Memorial Union"
buildings
# Out:
# {'UCC': 'University Capitol Center',
#  'PBB': 'Pappajohn Business Building',
#  'PC': 'Pomerantz Center',
#  'IMU': 'Iowa Memorial Union'}

# %% [markdown]
# You can add a new key-value pair by declaring the new key and then assigning its value.

# %%
buildings["IMU"] = "Iowa Memorial Union (New)"
buildings
# Out:
# {'UCC': 'University Capitol Center',
#  'PBB': 'Pappajohn Business Building',
#  'PC': 'Pomerantz Center',
#  'IMU': 'Iowa Memorial Union (New)'}

# %% [markdown]
# You can update the value for any of the existing keys.

# %%
"IMU" in buildings
# Out:
# True

# %% [markdown]
# You can check if a key is in a dictionary using the `in` operator.

# %%
"SH" in buildings
# Out:
# False

# %%
len(buildings)
# Out:
# 4

# %% [markdown]
# The length of a dictionary is the number of key-value mappings in the dictionary.

# %%
buildings = {
    "UCC": {"name": "University Capitol Center",
            "address": "200 South Capitol Street, Iowa City, IA 52240", 
            "year": 1981}, 
    "PBB": {"name": "Pappajohn Business Building",
            "address": "21 East Market Street, Iowa City, IA 52242",
            "year": 1993},
    "IMU": {"name": "Iowa Memorial Union", 
            "address": "125 North Madison Street, Iowa City, IA 52242", 
            "year": 1925}
}

# %% [markdown]
# A value of a key in a dictionary can be any object in Python.

# %%
buildings["UCC"]
# Out:
# {'name': 'University Capitol Center',
#  'address': '200 South Capitol Street, Iowa City, IA 52240',
#  'year': 1981}

# %%
buildings["UCC"]["name"]
# Out:
# 'University Capitol Center'

# %%
buildings["UCC"]["address"]
# Out:
# '200 South Capitol Street, Iowa City, IA 52240'

# %% [markdown]
# ## Sets

# %% [markdown]
# A set is a collection that is unordered, mutable, unindexed, and written with curly brackets. It allows no duplicates. Dictionaries and sets are both written with curly brackets, but sets only have keys with no corresponding values to those keys.

# %%
s = {}

# %%
s = {"cat", "dog", "bird"}
print(s, type(s))

# %% [markdown]
# You can create a set by listing its elements in a pair of matching curly braces.

# %%
s[0]

# %% [markdown]
# Sets are not indexed, which means you cannot access the elements using their index positions.

# %%
"dog" in s

# %%
"cow" in s

# %% [markdown]
# ![](https://matcha.fyi/content/images/2021/06/2-1.png)

# %% [markdown]
# ### Set Methods

# %%
s

# %%
s.add("fish")
s

# %% [markdown]
# The `add` method adds an element to the set. Note that there is no `append` method in sets, unlike in lists.

# %%
s.add("fish")
s

# %% [markdown]
# Sets do not allow duplicate values. If the element to be added already exists, it does not add the element.

# %%
s.update({"elephant", "horse", "whale"})
s

# %% [markdown]
# The `update` method updates the current set by adding items from another set.

# %% [markdown]
# Note that the `add` method adds a single element to a set, while the `update` method adds a group of elements.

# %%
s.remove("cat")
s

# %% [markdown]
# The `remove` method removes the specified element from the set.

# %% [markdown]
# ![](https://www.learnbyexample.org/wp-content/uploads/python/Python-Set-Operatioons.png)

# %%
s1 = {1, 2, 3, 4, 5}
s2 = {1, 3, 5, 7, 9}

s1.union(s2)
# Out:
# {1, 2, 3, 4, 5, 7, 9}

# %% [markdown]
# The `union` method returns a set that contains all items from both sets.

# %%
s1 = {1, 2, 3, 4, 5}
s2 = {1, 3, 5, 7, 9}

s1 | s2                         # vertical bar as a union operator

# %% [markdown]
# `s1 | s2` is equivalent to `s1.union(s2)`.

# %%
s1 = {1, 2, 3, 4, 5}
s2 = {1, 3, 5, 7, 9}

s1.intersection(s2)

# %% [markdown]
# The `intersection` method returns a set that contains only items that exist in both sets.

# %%
s1 = {1, 2, 3, 4, 5}
s2 = {1, 3, 5, 7, 9}

s1 & s2                         # ampersand as an intersection operator

# %% [markdown]
# `s1 & s2` is equivalent to `s1.intersection(s2)`.

# %%
s1 = {1, 2, 3, 4, 5}
s2 = {1, 3, 5, 7, 9}

s1.difference(s2)

# %% [markdown]
# The `difference` method returns a set that contains the difference between two sets, i.e., the returned set contains items that exist only in the first set, and not in both sets.

# %%
s1 = {1, 2, 3, 4, 5}
s2 = {1, 3, 5, 7, 9}

s1 - s2

# %% [markdown]
# `s1 - s2` is equivalent to `s1.difference(s2)`.

# %%
s1.symmetric_difference(s2)

# %% [markdown]
# The `symmetric_difference` method returns a set that contains all items from both sets, but not the items that are present in both sets, i.e., the returned set contains a mix of items that are not present in both sets.

# %%
s1 = {1, 2, 3, 4, 5}
s2 = {1, 3, 5, 7, 9}

s1 ^ s2

# %% [markdown]
# `s1 ^ s2` is equivalent to `s1.symmetric_difference(s2)`.

# %%
s1 = {1, 2, 3, 4, 5}
s2 = {1, 3, 5, 7, 9}
s3 = {2, 4, 6, 8, 10}

# %% [markdown]
# You can perform set operations on more than two sets.

# %%
set.union(s1, s2, s3)

# %%
s1 | s2 | s3
