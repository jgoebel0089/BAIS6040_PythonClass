# %% [markdown]
# # In-Class Exercise 2: Python Collections, Functions, and If-Else Branching
#
# Follow the instructions in each cell. Write your code where indicated.

# %% [markdown]
# # Exercise 0: String Activity

# %%
# Write 3 of the string slices from the activity in class in 3 separate cells

# %%
S = "a"
print(S[0])
# Out:
# a

# %% [markdown]
# # Exercise 1: Lists and Basic Operations

# %%
#1a. Create a list called `scores` with the following values:
# 88, 92, 79, 93, 85

# %%
# 1b. Print the number of scores in the list

# %%
# 1c. Print the maximum and minimum score from the list

# %% [markdown]
# # Exercise 2: Dictionaries
#
# ### 2a. Create a dictionary called `student_ages`
# ### with the following key-value pairs:
# ### "Alex": 26, "Jordan": 32, "Taylor": 59

# %%
# 2b. Print Jordan's age

# YOUR CODE HERE

# %%
# 2c. Add a new student "Morgan" with age 41

# YOUR CODE HERE

# %% [markdown]
# ## Exercise 3 - Sets
# In a coding cell below, create the sets and then find union using | and intersection using &

# %% [markdown]
# 1\. Manually create a set `s1` of even numbers between 1 and 20.

# %% [markdown]
# 2\. Manually create a set `s2` of multiples of 3 between 1 and 20.

# %% [markdown]
# 3\. Get the union of `s1` and `s2`.

# %% [markdown]
# 4\. Get the intersection of `s1` and `s2`.

# %% [markdown]
# # Functions

# %%
# Your answer here - Fill the code  (You'll need to change what's inside the function and what it returns)
def concatenate(s1, s2):
    s1 * s2
    return 
    
# Test the function here
concatenate("I'm coding with", "Python")     # Output: 'I'm coding with Python'

# %% [markdown]
# # Branching

# %% [markdown]
# Write an <b>if-elif-else/b> statement that prints "*x is greater than y.*" if `x` is greater than `y`, "*x is less than y.*" if `x` is less than `y`, and "*x equals y.*" otherwise.  Test with different values of x and y.

# %%
# Your answer here

# %% [markdown]
# Have the user input two weather variables: temp and precip. You will need to convert temp to a float and precip can be a "Yes" or "No" string.
#
# * First check if there is no precipitation and the temperature is > 80, print("It is too hot!")
# * Then, if that is false, check if the temperature is < 32 and there is precipitation, then print("Not dealing with snow!")
# * Otherwise, print ("I can work with this weather!")

# %%
# Your answer here
temp = input()
precip = input()

# %% [markdown]
# # Functions and Branching

# %%
# Write a function letter_grade(score) using if/elif/else logic inside
# A: 90+, B: 80–89, C: 70–79, D: <70

# Test the function on 3 scores: 75, 90, 80
# YOUR CODE HERE
