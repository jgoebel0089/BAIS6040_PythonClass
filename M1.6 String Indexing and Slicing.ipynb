# %% [markdown]
# # Data Programming in Python | BAIS:6040
# # Module 1.6 Notebook Demonstration - String Indexing and Slicing

# %% [markdown]
# ### Topics to be covered:
# - String slicing
# - String indexing

# %% [markdown]
# ## Basic Data Types of Python

# %% [markdown]
# - Numbers
# - **Strings**
# - Collections
#     - Lists
#     - Tuples
#     - Dictionaries
#     - Sets

# %% [markdown]
# ## Strings

# %%
s = "How are you?"

# %% [markdown]
# A string can have any characters including Alphabet letters, whitespaces, and punctuation marks. A string can be enclosed in matching single quotes (') or double quotes ("); either is fine.

# %% [markdown]
# `s` is a string variable.

# %%
print(s, type(s))
# Out:
# How are you? <class 'str'>

# %% [markdown]
# ### String Indexing and Slicing

# %% [markdown]
# A string, as well as any iterable object in Python, can be indexed and sliced.

# %% [markdown]
# ![alt text](string_index.png)

# %% [markdown]
# A Python index starts from 0, increments by 1, and ends at the length -1.

# %%
s = "This is text."
s
# Out:
# 'This is text.'

# %%
s[1]
# Out:
# 'h'

# %% [markdown]
# You can access a character in a string by referring to the index position inside matching square brackets.

# %%
s[12]
# Out:
# '.'

# %%
s[13]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 s[13]
#
# IndexError: string index out of range

# %% [markdown]
# ``` str_object[start:stop:step] ```

# %% [markdown]
# The slicing starts with the `start` index (inclusive) and ends at `stop` index (exclusive). The `step` parameter is used to specify the steps to take from `start` to `stop` index. The three parameters are all optional.

# %%
s[0:4]
# Out:
# 'This'

# %% [markdown]
# Note that the `start` parameter is inclusive, whereas the `stop` parameter is exclusive. Technically, `s[i:j]` will return a string starting with `s[i]` and ending with `s[j-1]`, not `s[j]`.

# %%
s[:4]
# Out:
# 'This'

# %% [markdown]
# You can skip the starting index 0, if it starts from 0, which is the beginning. `s[:n]` is the easiest way to get the first `n` characters in a string.

# %%
s[8:13]
# Out:
# 'text.'

# %%
s[8:]
# Out:
# 'text.'

# %% [markdown]
# You can skip the stopping index, if it goes to the end of the string.

# %%
s[:]
# Out:
# 'This is text.'

# %% [markdown]
# You can skip both the starting and stopping indices if it starts from 0 and goes to the end of the string.

# %%
s[::2]      # Stepping by 2
# Out:
# 'Ti stx.'

# %%
s[::3]      # Stepping by 3
# Out:
# 'Tsse.'

# %%
s[::-1]     # Stepping by -1, which means reversing the string
# Out:
# '.txet si sihT'

# %% [markdown]
# Python also indexes the arrays backwards, using negative numbers.

# %%
s
# Out:
# 'This is text.'

# %%
s[-1]
# Out:
# '.'

# %%
s[-5]
# Out:
# 't'

# %%
s[-5:]
# Out:
# 'text.'

# %% [markdown]
# `s[-n:]` is the easiest way to get the last `n` characters in a string.

# %%
s
# Out:
# 'This is text.'

# %% [markdown]
# Note that the target string `s` has not changed at all. Indexing and slicing of strings returns a copy of string, not changing the target string.

# %%
s = s[:4]
s
# Out:
# 'This'

# %% [markdown]
# If you intend to change the target string by indexing or slicing, make sure to store the outcome back in the target string.
