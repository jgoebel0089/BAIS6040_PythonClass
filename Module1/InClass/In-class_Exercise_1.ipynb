# %% [markdown]
# # In-Class Exercise: Numbers, Strings, and Debugging   1-21-26 BAIS6040 (Created with help of ChatGPT)
#
# Work through each cell in order.

# %%
# CELL 1: Numbers (Warm-Up)

a = 10
b = 3

# Add, subtract, multiply and divide the 2 numbers (a and b)
add = a + b
sub = a - b
mult = a * b
div = a / b
dubdiv = a // b
exp = a ** b

# Use print(a + b) to show the answer.
print("Addition", add)

# Then, what happens when you use // instead of / for division. Put a comment (#) how it is different.
print("Division", div)
print("Floor Division", dubdiv)

# Finally, raise a to the power of b with **
print("Exponent", exp)
# Out:
# Addition 13
# Division 3.3333333333333335
# Floor Division 3
# Exponent 1000

# %%
# CELL 2: Numbers (Student Exercise)
# TODO:
# 1. Create a variable called `price` with value 19.99
price = 19.99
# 2. Create a variable called `quantity` with value 3
quantity = 3
# 3. Compute the total cost and store it in `total`
total = price * quantity
# 4. Print the total cost
print("Total Cost", total)
# Out:
# Total Cost 59.97

# %%
# CELL 3: Strings Basics
# Use quotation marks to store your first and last name in the below variables. 

first_name = "Jacyn"
last_name = "Goebel"

full_name = first_name + " " + last_name

#Print out full name
print(full_name)

#Print out length of your full name using len()
len(full_name)
# Out:
# Jacyn Goebel
# 12

# %%
word = input("Please write a word")
# Out:
# Please write a word data

# %%
# CELL 4: String Indexing and Slicing  (Don't need to do anything here. Use this for Cell 5)

word = "debugging"

print(word[0])
print(word[-1])
print(word[0:5])
print(word[5:])
# Out:
# d
# g
# debug
# ging

# %%
# CELL 5: Strings (Student Exercise)

message = "Data Programming is fun"

# TODO:
# 1. Print only the word "Programming"
print(message[5:16])
# 2. Print the message in all uppercase
print(message.upper())
# 3. Print the number of characters in the message
print(len(message))
# Out:
# Programming
# DATA PROGRAMMING IS FUN
# 23

# %%
# CELL 7: Debugging Exercise #1
# TODO: Fix the code above so it prints:
# I am 25 years old
age = 25
print("I am " + str(age) + " years old")
# Out:
# I am 25 years old

# %%
# CELL 8: Debugging Exercise #2  - Use casting to fix the below code. Change either x or y using str() or int()

x = 5
y = "2"
result = x + int(y)
print("The result is", result)
# Out:
# The result is 7

# %%
# Cell 9: Numbers – Converting Input
# Goal: Ask the user for two numbers and print their sum


x = float(input("Enter a number: "))
y = float(input("Enter another number: "))


print(x + y) # BUG: adds strings instead of numbers   - same as Cell 8 use float(variable) to cast as a number
# Out:
# Enter a number:  5
# Enter another number:  6
# 11.0

# %%
# --------------------------------------------------
# Cell 10: Strings – Method vs Property
# Goal: Print the string in all uppercase


message = "fix this bug"
print(message.upper) # BUG: method not called  Make sure to use parentheses () after upper
# Out:
# FIX THIS BUG

# %%
#Cell 11 - Write a multiline comment summarizing this exercise. Just need 2-3 sentences.
#Introductory exercises learning the interface of jupyter notebook
#Learning basics of python syntax, operation, and functionality
