# %% [markdown]
# # Data Programming in Python | BAIS:6040
# # In-class Exercise 1

# %% [markdown]
# ### Strings

# %% [markdown]
# Download and open declaration.txt and constitution.txt. Copy and paste the text inside a multi-line string in Python

# %%
"""
Multiline comment
To set a multiline string object use the three quotation marks like in this cell.
"""

comment = """
Will this work?
I really hope so!
"""

# %%
print(comment)
# Out:
# Will this work?
# I really hope so!

# %%
comment
# Out:
# '\nWill this work?\nI really hope so!\n'

# %%
declaration =

# %%
constitution =

# %% [markdown]
# ### Now use string inclusion to see which of these 3 words is not in the U.S. constitution
# america
# democracy
# taxes
#
# Remember to check both upper and lower case since Python is case sensitive
#
# ***Do these checks in separate cells and after these checks use a Markdown cell to give the answer in a sentence.***

# %% [markdown]
# # Using the length built-in python function (len), save how many characters each document contains.
#
# ### Then, see how much longer the Constitution is than then Declaration of Independence.
# #### i.e. The Constitution is ____ times longer than the Declaration of Independence.

# %%
constitution_len

# %%
declaration_len

# %%
print()

# %% [markdown]
# # Numbers

# %% [markdown]
# Visit  https://studentaid.gov/understand-aid/types/loans/interest-rates

# %% [markdown]
# You are a graduate Iowa MSBA student taking out $20,000 in direct unsubsidized loans. It is the first month of interest accruing, and it has been 25 days since your last payment (aka your loan started).
#
# ***How much interest has accrued?***

# %%
outstanding_principal =

# %%
# This is your daily interest rate. Assume 365 days in a year
interest_factor =

# %%
num_days =

# %%
interest_accrued =

# %%
print("The total interest accrued is ")
