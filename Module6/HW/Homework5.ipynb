# %% [markdown]
# # Data Programming in Python | BAIS:6040
# # Homework 5. Visualization

# %% [markdown]
# ## Instructions

# %% [markdown]
# - Fill in the Python statements needed to complete all the questions below.
# - Program everything inside this notebook.
# - Use only one cell per question.
# - Each code cell must be run with no errors.
# - Do not contain any unnecessary code in your answer. (Only the final outcome will be regarded as your answer.)
# - If the question requests that you store information in a certain variable, use the specific variables name (case sensitive).
# - All problems must be solved in a programmable way.
# - When you are done, make sure to save your notebook and then click Restart & Run All before subimission to create a clean version.

# %% [markdown]
# #

# %% [markdown]
# ## Questions - NumPy

# %% [markdown]
# 1\. To use NumPy, import the NumPy package as np.

# %%
# Your answer here

# %% [markdown]
# 2\. Set the random seed to 0 and then create a 10 x 10 array `x` of random integers between 1 (inclusive) and 100 (inclusive).

# %%
# Your answer here

# %%
# Check your answer here. (Do not make any change to this cell. Just run this cell.)
x

# %% [markdown]
# 3\. Create a 10 x 10 array `y` of integers from 100 (inclusive) to 1 (inclusive), such that the first row has integers from 100 to 91, the second row from 90 to 81, and so on and so forth. Note that order of values matters.

# %%
# Your answer here

# %%
# Check your answer here. (Do not make any change to this cell. Just run this cell.)
y

# %% [markdown]
# 4\. Select all the values that are in the first 3 rows and the last 7 columns of `x` and save the resulting array in `x_top_right`. Select all the values that are in the last 7 rows and the first 3 columns of `y` and save the resulting array in `y_bottom_left`.

# %%
# Your answer here

# %%
# Check your answer here. (Do not make any change to this cell. Just run this cell.)
x_top_right

# %%
# Check your answer here. (Do not make any change to this cell. Just run this cell.)
y_bottom_left

# %% [markdown]
# 5\. Before we calculate the dot product of `x_top_right` and `y_bottom_left`, we want to confirm that the number of columns of `x_top_right` equals the number of rows of `y_bottom_left`. Compare the two values using the equality operator (==) and save the resulting True value in `ans9`. Do not directly put their values (i.e., 7) in the comparison.

# %%
# Your answer here

# %%
# Check your answer here. (Do not make any change to this cell. Just run this cell.)
ans9

# %% [markdown]
# 6\. Calculate the dot product of `x_top_right` and `y_bottom_left` and then save the resulting array in the variable `dot_prod`.

# %%
# Your answer here

# %%
# Check your answer here. (Do not make any change to this cell. Just run this cell.)
dot_prod

# %% [markdown]
# # Data Visualization Questions

# %% [markdown]
# For questions 1 to 3, you have a dataframe `dfdi` with the features of diamonds.

# %%
# Do not make any change to this cell. Just run this cell.
from seaborn import load_dataset

dfdi = load_dataset("diamonds")
dfdi

# %% [markdown]
# 1\. Plot a box plot that displays the distributions of the 3 columns `x`, `y`, and `z` in `dfdi`. Set the `figsize` to 15 x 7. Customize other arguments, including title, labels, alignment and so on.

# %%
# Your answer here

# %% [markdown]
# 2\. Plot a histogram that plots the distribution of `price` in `dfdi` with 10 bins. Customize the figuresize and other arguments, including title, labels, alignment and so on.

# %%
# Your answer here

# %% [markdown]
# 3\. There are 7 unique colors in the `color` column of `dfdi`: *D*, *E*, *F*, *G*, *H*, *I*, and *J*. Plot a pie chart and a bar plot in one figure, two columns in one row. The pie chart displays the distribution(percentage) of the count of each color and the bar plot displays the mean prices for the 7 colors. Set the `figsize` to 14 x 7. Use the <b>groupby</b> method to calculate the mean prices for the 7 colors.

# %%
# Your answer here

# %% [markdown]
# Let's use seaborn to load the titanic dataset to use for our dataframe. You may also use the titanic.csv file that is on the Homework 5 ICON assignment page.

# %%
import pandas as pd 
import matplotlib.pyplot as plt
from seaborn import load_dataset

dft = load_dataset('titanic')
#dft = pd.read_csv("titanic.csv")  # you may need to change the directory and the columns are uppercase. 
dft.head()

# %% [markdown]
# 4\. Plot a histogram that plots the distribution of `Age` in `dft` with 8 bins. Set the `figsize` to (10, 6). Set the `xlabel` as "*Age*", `ylabel` as "*Number of Passengers*" add a title "*Distribution of Passenger Age*".

# %%
# Your answer here
plt.figure(figsize=(10, 6))

# Fill your code below


plt.show()

# %% [markdown]
# 5\. Plot a Pie Chart to show the total number of passergers survived or not (died). Set the `startangle` as 90, add the percentage label inside the pie with the format `%.1f%%`, and split the two parts by setting the `explode` as \[0, 0.1\], set the color as "green" for survived group and "gray" for non-survived group.

# %%
# Your answer here
# Fill your code below
count = 


# Show the plot
plt.show()

# %% [markdown]
# 6\. Plot two pie charts, two columns in one row. Set the `figsize` to 14 x 7. The left pie chart shows the passenger class `Pclass` distribution for the survived passengers; the pie chart on the right shows the `Pclass` distribution for passengers who didn't survive. Add the text labels (given in the `labels` list) and the percentage label inside each pie chart with the format `%.1f%%`, and add a title for each pie chart.

# %%
# Your answer here
# Fill your code below
fig, axs = plt.subplots(1, 2, figsize=(14,7))

ax1 = axs[0]
ax2 = axs[1]

survived = dft[dft['survived']==1]
not_survived = dft[dft['survived']==0]





# Pie chart on the left is for passengers who survived
#Use ax1


# Pie chart on the right for passengers who died
#Use ax2


# Show the plot
plt.show()

# %% [markdown]
# 7\. Plot a box plot that displays the `Fare` for each `Pclass`. Set the `xlabel` to "*Passenger Class*", `ylabel` to "*Fare*", and `title` to "*Boxplot of Fares by Passenger Class*".

# %%
# Your answer here

plt.show()
