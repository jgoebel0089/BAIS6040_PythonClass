# %%
fh = open("../Room7/test.txt", "r") #r, read the file
fh.read()
# Out:
# 'Test script to read from Room7'

# %%
pi=3.14
x=5.0
fh = open("../Room9/test.txt", "w") #w, write onto the file
fh.write(str(pi))
fh.write("\n")
fh.write(str(x))
fh.close()

# %%
pi=3.14
x=5.0
fh = open("../Room10/test.txt", "w") #w, write onto the file
fh.write(str(pi))
fh.write("\n")
fh.write(str(x))
fh.close()

# %%
list1 = [5,5,5,5,0]
list2 = [6,5,4,3,2]

with open("test.txt", "a") as fh:
    fh.write(f"{list1}\n")
    fh.write(f"{list2}\n")

# %%
dict1 = {"Lol": "Laugh out loud", "Idk": "I dont know"}

with open("test.txt", "x") as fh:
    fh.write(f"{dict1}")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[17], line 3
#       1 dict1 = {"Lol": "Laugh out loud", "Idk": "I dont know"}
# ----> 3 with open("test.txt", "x") as fh:
#       4     fh.write(f"{dict1}")
#
# File /usr/local/lib/python3.11/site-packages/IPython/core/interactiveshell.py:325, in _modified_open(file, *args, **kwargs)
#     318 if file in {0, 1, 2}:
#     319     raise ValueError(
#     320         f"IPython won't let you open fd={file} by default "
#     321         "as it is likely to crash IPython. If you know what you are doing, "
#     322         "you can use builtins' open."
#     323     )
# --> 325 return io_open(file, *args, **kwargs)
#
# FileExistsError: [Errno 17] File exists: 'test.txt'

# %%
dict1 = {"Lol": "Laugh out loud", "Idk": "I dont know"}

with open("test2.txt", "x") as fh:
    fh.write(f"{dict1}")

# %%
set1 = {1,2,3,4}
with open("test.txt", "x") as fh:
    fh.write(f"{set1}")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[22], line 2
#       1 set1 = {1,2,3,4}
# ----> 2 with open("test.txt", "x") as fh:
#       3     fh.write(f"{set1}")
#
# File /usr/local/lib/python3.11/site-packages/IPython/core/interactiveshell.py:325, in _modified_open(file, *args, **kwargs)
#     318 if file in {0, 1, 2}:
#     319     raise ValueError(
#     320         f"IPython won't let you open fd={file} by default "
#     321         "as it is likely to crash IPython. If you know what you are doing, "
#     322         "you can use builtins' open."
#     323     )
# --> 325 return io_open(file, *args, **kwargs)
#
# FileExistsError: [Errno 17] File exists: 'test.txt'

# %%
set1 = {1,2,3,4}
with open("test3.txt", "x") as fh:
    fh.write(f"{set1}")
