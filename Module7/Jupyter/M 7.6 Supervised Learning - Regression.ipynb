# %% [markdown]
# # Data Programming in Python | BAIS:6040
# # Notebook Demonstration 7.6 Supervised Learning - Regression

# %% [markdown]
# With Regression, you are predicting a continuous target variable instead of a class or category like in classification.

# %% [markdown]
# We'll be using the mpg dataset in seaborn. The mpg dataset contains information about miles per gallon for different car models and their attributes. It includes features such as miles per gallon, number of cylinders in the engine, engine displacement, engine horsepower, vehicle weight, acceleration, model year, origin of the car, and car model name.

# %% [markdown]
# **Features and Characteristics**
#
# - mpg: Miles per gallon (numerical)
# - cylinders: Number of cylinders in the engine (numerical)
# - displacement: Engine displacement in cubic inches (numerical)
# - horsepower: Engine horsepower (numerical)
# - weight: Vehicle weight in pounds (numerical)
# - acceleration: Acceleration in seconds from 0 to 60 mph (numerical)
# - model_year: Model year (categorical)
# - origin: Origin of the car (categorical)
# - name: Car model name (string)

# %%
import pandas as pd
from seaborn import load_dataset

dfm = load_dataset("mpg")

# %%
dfm

# %%
dfm.info()

# %%
dfm.dropna(inplace=True)

# %% [markdown]
# Assume that we can use features `cylinders`, `displacement`, `horsepower`, `weight`, `acceleration`, `model_year` to predict the `mpg`.

# %%
features = ["cylinders", "displacement", "horsepower", "weight", "acceleration"]
target = "mpg"

# %% [markdown]
# We need two variables, `X` as the features set and `y` as the target set. Select the feature columns in `dfm` and save the resulting dataframe in the variable `X`. Likewise, select the target column in `dfm` and save it in the variable `y`.

# %%
# Your answer here
X = dfm[features]
y = dfm[target]

# %% [markdown]
# Split `X` and `y` into 80% of training sets `X_train` and `y_train` and 20% of test sets `X_test` and `y_test`. Set `random_state` to 0.

# %%
# Your answer here
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=0)

# %% [markdown]
# You can initialize a k-NN model object `knn` as follows. The number of neighbors `n_neighbors` is set to 3, which means it will consider the three closest neighbors. Note, this is a regressor instead of a classifier.*

# %%
from sklearn.neighbors import KNeighborsRegressor

knn = KNeighborsRegressor(n_neighbors=3)

# %% [markdown]
# Fit the k-NN model `knn` using the two training sets `X_train` and `y_train`.

# %%
# Your answer here
knn.fit(X_train, y_train)

# %% [markdown]
# Get the training score and test score, respectively.

# %%
# Your answer here
knn.score(X_train, y_train)

# %%
knn.score(X_test, y_test)

# %%
X_test

# %%
y_test

# %% [markdown]
# Suppose there is another car with the following record. What's the estimated mpg of this car using your k-NN model?

# %%
car = {"cylinders": 8,
          "displacement": 283,
          "horsepower": 140,
          "weight": 3890,
          "acceleration": 14.6
          }

new_car = [car["cylinders"], car["displacement"], car["horsepower"], car["weight"], car["acceleration"]]
X_new = [new_car]
X_new

# %%
import pandas as pd

X_new = pd.DataFrame(data=X_new, columns=features)
X_new

# %%
# Your answer here
knn.predict(X_new)

# %% [markdown]
# You can initialize a linear regression model object `lr` as follows:

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()

# %% [markdown]
# Fit the linear regression model `lr` using the two training sets.

# %%
# Your answer here
lr.fit(X_train, y_train)

# %% [markdown]
# Get the training score and test score, respectively.

# %%
# Your answer here
lr.score(X_train, y_train)

# %%
lr.score(X_test, y_test)

# %% [markdown]
# What's the estimated mpg for the new car in Q5?

# %%
# Your answer here
lr.predict(X_new)
